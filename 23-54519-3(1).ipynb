# %%
# Romanian Map
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# DFS using Stack (List)
def dfs(startingNode, destinationNode, G):
    reached = []
    expand_sequence = []
    stack = []

    snode = {'City': startingNode, 'Path cost': 0, 'Path': [startingNode]}
    stack.append(snode)
    reached.append(startingNode)

    while len(stack) > 0:
        print("Stack:", stack)

        unode = stack.pop()   # LIFO
        u = unode['City']
        expand_sequence.append(u)
        print(u, "expanding..")

        if u == destinationNode:
            print("Expand sequence:", expand_sequence)
            print("Path:", unode['Path'])
            print("Total Cost:", unode['Path cost'])
            return unode

        for v in G[u].keys():
            if v not in reached:
                print(v, "generated.")
                cost = unode['Path cost'] + G[u][v]
                path = unode['Path'] + [v]
                vnode = {'City': v, 'Path cost': cost, 'Path': path}
                stack.append(vnode)
                reached.append(v)

    print("Failed")

# Run DFS
dfs('Arad', 'Bucharest', romanian_map)
# Out:
# Stack: [{'City': 'Arad', 'Path cost': 0, 'Path': ['Arad']}]
# Arad expanding..
# Sibiu generated.
# Zerind generated.
# Timisoara generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}]
# Timisoara expanding..
# Lugoj generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}]
# Lugoj expanding..
# Mehadia generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Mehadia', 'Path cost': 299, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}]
# Mehadia expanding..
# Drobeta generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Drobeta', 'Path cost': 374, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']}]
# Drobeta expanding..
# Craiova generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Craiova', 'Path cost': 494, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']}]
# Craiova expanding..
# Rimnicu generated.
# Pitesti generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Rimnicu', 'Path cost': 640, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu']}, {'City': 'Pitesti', 'Path cost': 632, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']}]
# Pitesti expanding..
# Bucharest generated.
# Stack: [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Rimnicu', 'Path cost': 640, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu']}, {'City': 'Bucharest', 'Path cost': 733, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']}]
# Bucharest expanding..
# Expand sequence: ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# Path: ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# Total Cost: 733
# {'City': 'Bucharest',
#  'Path cost': 733,
#  'Path': ['Arad',
#   'Timisoara',
#   'Lugoj',
#   'Mehadia',
#   'Drobeta',
#   'Craiova',
#   'Pitesti',
#   'Bucharest']}
